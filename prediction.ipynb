# %%
# Step 1: Import Libraries and Load the Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
# Load the IMDB dataset word index
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
# Load the pre-trained model with ReLU activation
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\layers\core\embedding.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load the pre-trained model with ReLU activation
# ----> 2 model = load_model('simple_rnn_imdb.h5')
#       3 model.summary()
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\saving\saving_api.py:195, in load_model(filepath, custom_objects, compile, safe_mode)
#     188     return saving_lib.load_model(
#     189         filepath,
#     190         custom_objects=custom_objects,
#     191         compile=compile,
#     192         safe_mode=safe_mode,
#     193     )
#     194 if str(filepath).endswith((".h5", ".hdf5")):
# --> 195     return legacy_h5_format.load_model_from_hdf5(
#     196         filepath,
#     197         custom_objects=custom_objects,
#     198         compile=compile,
#     199         safe_mode=safe_mode,
#     200     )
#     202 # Check for Orbax checkpoint directory using utility function
#     203 if is_orbax_checkpoint(filepath):
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:139, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     137 safe_mode_scope = serialization_lib.SafeModeScope(safe_mode)
#     138 with legacy_scope, safe_mode_scope:
# --> 139     model = saving_utils.model_from_config(
#     140         model_config, custom_objects=custom_objects
#     141     )
#     143     # set weights
#     144     load_weights_from_hdf5_group(
#     145         safe_get_h5_group(f, "model_weights"), model
#     146     )
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\legacy\saving\serialization.py:492, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     489 custom_objects = custom_objects or {}
#     491 if "custom_objects" in arg_spec.args:
# --> 492     deserialized_obj = cls.from_config(
#     493         cls_config,
#     494         custom_objects={
#     495             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     496             **custom_objects,
#     497         },
#     498     )
#     499 else:
#     500     with object_registration.CustomObjectScope(custom_objects):
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\models\sequential.py:385, in Sequential.from_config(cls, config, custom_objects)
#     381 for layer_config in layer_configs:
#     382     if "module" not in layer_config:
#     383         # Legacy format deserialization (no "module" key)
#     384         # used for H5 and SavedModel formats
# --> 385         layer = saving_utils.model_from_config(
#     386             layer_config,
#     387             custom_objects=custom_objects,
#     388         )
#     389     else:
#     390         layer = serialization_lib.deserialize_keras_object(
#     391             layer_config,
#     392             custom_objects=custom_objects,
#     393         )
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\legacy\saving\serialization.py:501, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     499     else:
#     500         with object_registration.CustomObjectScope(custom_objects):
# --> 501             deserialized_obj = cls.from_config(cls_config)
#     502 else:
#     503     # Then `cls` may be a function returning a class.
#     504     # in this case by convention `config` holds
#     505     # the kwargs of the function.
#     506     custom_objects = custom_objects or {}
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:449, in SimpleRNN.from_config(cls, config)
#     447 @classmethod
#     448 def from_config(cls, config):
# --> 449     return cls(**config)
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:341, in SimpleRNN.__init__(self, units, activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, return_sequences, return_state, go_backwards, stateful, unroll, seed, **kwargs)
#     296 def __init__(
#     297     self,
#     298     units,
#    (...)    319     **kwargs,
#     320 ):
#     321     cell = SimpleRNNCell(
#     322         units,
#     323         activation=activation,
#    (...)    339         name="simple_rnn_cell",
#     340     )
# --> 341     super().__init__(
#     342         cell,
#     343         return_sequences=return_sequences,
#     344         return_state=return_state,
#     345         go_backwards=go_backwards,
#     346         stateful=stateful,
#     347         unroll=unroll,
#     348         **kwargs,
#     349     )
#     350     self.input_spec = [InputSpec(ndim=3)]
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199, in RNN.__init__(self, cell, return_sequences, return_state, go_backwards, stateful, unroll, zero_output_for_mask, **kwargs)
#     192 if "state_size" not in dir(cell):
#     193     raise ValueError(
#     194         "The RNN cell should have a `state_size` attribute "
#     195         "(single integer or list of integers, "
#     196         "one integer per RNN state). "
#     197         f"Received: cell={cell}"
#     198     )
# --> 199 super().__init__(**kwargs)
#     201 # If True, the output for masked timestep will be zeros, whereas in the
#     202 # False case, output from previous timestep is returned for masked
#     203 # timestep.
#     204 self.zero_output_for_mask = zero_output_for_mask
#
# File d:\Projects\Prediction using Simple RNN\.venv\Lib\site-packages\keras\src\layers\layer.py:295, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     293     self._input_shape_arg = input_shape_arg
#     294 if kwargs:
# --> 295     raise ValueError(
#     296         "Unrecognized keyword arguments "
#     297         f"passed to {self.__class__.__name__}: {kwargs}"
#     298     )
#     300 self._path = None  # Will be determined in `build_wrapper`
#     301 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to SimpleRNN: {'time_major': False}

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0
